# %%
import pandas as pd

# %%
info_dict = {
    'dk1' : 'Price in DK1-area [DKK/MWh]',
    'dk2' : 'Price in DK2-area [DKK/MWh]',
    'no2' : 'Price in NO2-area [DKK/MWh]',
    'se3' : 'Price in SE3-area [DKK/MWh]',
    'se4' : 'Price in SE4-area [DKK/MWh]',
    'system' : '"system-level" price [DKK/MWh]',
    'central-production-dk1' : 'Production from "big" central power plants [MWh]',
    'central-production-dk2' : 'Production from "big" central power plants [MWh]',
    'exchange-continent-dk1' : 'Exchange between DK1 and DE [MWh]',
    'exchange-greatbelt' : 'Exchange between DK1 and DK2 [MWh]',
    'exchange-nordiccountries-dk1' : 'Exchange between DK1 and NO2 [MWh]',
    'exchange-nordiccountries-dk2' : 'Exchange between DK2 and SE4 [MWh]',
    'gross-consumption-dk1' : 'Consumption incl. heat loss',
    'gross-consumption-dk2 ' : 'Consumption incl. heat loss',
    'net-consumption-dk1' : 'Consumption excl. heat loss',
    'net-consumption-dk2' : 'Consumption excl. heat loss',
    'onshore-wind-dk1' : 'Production of onshore-wind in MWh',
    'onshore-wind-dk2' : 'Production of onshore-wind in MWh',
    'offshore-wind-dk1' : 'Production of offshore-wind in MWh',
    'offshore-wind-dk2' : 'Production of offshore-wind in MWh',
    'solarpower-dk1' : 'Production of electricity from Solar cells [MWh]',
    'solarpower-dk2' : 'Production of electricity from Solar cells [MWh]',
    'electricboiler-consumption-dk1' : 'Consumption from electric boilers [MWh]',
    'electricboiler-consumption-dk2' : 'Consumption from electric boilers [MWh]',
    'localpower-production-dk1'  : 'Production from Heat and Power units [MWh]',
    'localpower-production-dk2'  : 'Production from Heat and Power units [MWh]',
    'sun'  :  'minutes of sun in a given hour',
    'temperature'  :  'temperature in Celcius for a given hour',
    'wind' :  'Avg. wind speed in a given hour',
    'hour'  : 'Hour of day between 0 and 23',
    'weekday'  : 'Monday=0, ...., Sunday=6',
    'pricebin'  : 'Which percentile the current price is in [0-99]'
}

# %%
data = pd.DataFrame.from_dict(info_dict, orient='index', columns=['Description'])

# %%
data
# Out:
#                                                                      Description
# dk1                                                  Price in DK1-area [DKK/MWh]
# dk2                                                  Price in DK2-area [DKK/MWh]
# no2                                                  Price in NO2-area [DKK/MWh]
# se3                                                  Price in SE3-area [DKK/MWh]
# se4                                                  Price in SE4-area [DKK/MWh]
# system                                            "system-level" price [DKK/MWh]
# central-production-dk1          Production from "big" central power plants [MWh]
# central-production-dk2          Production from "big" central power plants [MWh]
# exchange-continent-dk1                         Exchange between DK1 and DE [MWh]
# exchange-greatbelt                            Exchange between DK1 and DK2 [MWh]
# exchange-nordiccountries-dk1                  Exchange between DK1 and NO2 [MWh]
# ...
